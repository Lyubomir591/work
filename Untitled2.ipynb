# %%
import pandas as pd
df = pd.read_csv('laptop_price.csv', encoding="latin-1")
df.Company.value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df.sort_values('Price_euros',ascending=False).describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df[df.Inches==df.Inches.min()][["Inches","Company","Price_euros"]]
# Out:
#       Inches Company  Price_euros
# 50      10.1  Lenovo       319.00
# 1082    10.1  Lenovo       646.27
# 1114    10.1  Lenovo       549.00
# 1126    10.1  Lenovo       479.00

# %%
df[df.Company=="HP"].sort_values("Price_euros",ascending=False).head(1)
# Out:
#      laptop_ID Company   Product     TypeName  Inches  \
# 749        758      HP  Zbook 17  Workstation    17.3
#
#                 ScreenResolution                            Cpu   Ram  \
# 749  IPS Panel Full HD 1920x1080  Intel Xeon E3-1535M v5 2.9GHz  16GB
#
#         Memory                   Gpu      OpSys Weight  Price_euros
# 749  256GB SSD  Nvidia Quadro M2000M  Windows 7    3kg       4389.0

# %%
df[(df.TypeName == "Ultrabook")&(df.Ram == "8GB")].shape[0]
# Out:
# 140

# %%
df[
    (((df.Ram == "16GB") | (df.Ram == "8GB")) & 
        (df.OpSys == "Windows 10")) &
        (df.Price_euros <= 500)
    ].sort_values('Price_euros').iloc[0:3].min()
# Out:
# laptop_ID                                       76
# Company                                       Acer
# Product             14-am079na (N3710/8GB/2TB/W10)
# TypeName                                  Notebook
# Inches                                        14.0
# ScreenResolution                          1366x768
# Cpu                       Intel Core i3 6006U 2GHz
# Ram                                            8GB
# Memory                                     1TB HDD
# Gpu                          Intel HD Graphics 405
# OpSys                                   Windows 10
# Weight                                        1.94
# Price_euros                                  389.0
# dtype: object

# %%
df[((df.Company == "MSI") & (df.Gpu == 'Nvidia GeForce GTX 1050 Ti')) &
      (~( df.Inches <15.6)) 
  ].sort_values("Price_euros")
# Out:
#       laptop_ID Company        Product TypeName  Inches   ScreenResolution  \
# 653         661     MSI     GL62M 7REX   Gaming    15.6  Full HD 1920x1080
# 330         336     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 108         111     MSI     GP62M 7REX   Gaming    15.6  Full HD 1920x1080
# 724         732     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 393         400     MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 1156       1174     MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
# 917         931     MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 653   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 330   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 108   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 724   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# ...

# %%
df.Weight = df.Weight.astype(str)

df.Weight = df.Weight.str.replace('kg','')
df.Weight = df.Weight.astype(float)

# %%
df[(df.TypeName == "Notebook") & (df.Weight < 2)].sort_values('Weight').head(5)
# Out:
#       laptop_ID  Company             Product  TypeName  Inches  \
# 862         873  Toshiba   Portege X30-D-10X  Notebook    13.3
# 479         486  Toshiba   Portege X30-D-10J  Notebook    13.3
# 895         906  Toshiba   Portege X30-D-10V  Notebook    13.3
# 310         315   Lenovo  IdeaPad 720S-13IKB  Notebook    13.3
# 1050       1064   Lenovo         ThinkPad X1  Notebook    14.0
#
#                  ScreenResolution                         Cpu   Ram  \
# 862             Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   4GB
# 479   IPS Panel Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 895             Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 310   IPS Panel Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 1050          IPS Panel 2560x1440  Intel Core i7 6600U 2.6GHz  16GB
#
#          Memory                    Gpu       OpSys  Weight  Price_euros
# 862   128GB SSD  Intel HD Graphics 620  Windows 10    1.05       1285.0
# ...

# %%
df[df.Price_euros == df.Price_euros.max()]
# Out:
#      laptop_ID Company    Product TypeName  Inches  \
# 196        200   Razer  Blade Pro   Gaming    17.3
#
#                         ScreenResolution                          Cpu   Ram  \
# 196  4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
#
#       Memory                      Gpu       OpSys  Weight  Price_euros
# 196  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000
